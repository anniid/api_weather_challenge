# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create base url, list to add cities to, and create a city counter so I can print the "city number" later
print("Compiling weather data")
print("---------------------------------------------------------")
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data_list=[]
city_number=0 #this will be my dataframe index, so, start at 0
for i, city in enumerate(cities):
    #create unique url per city
    city_url= f"{url}&q={city}"
    #print progress as you go
    print(f"Processing Record No. {city_number}: {city}")
    print("---------------------------------------------------------")
    #add one to the counter
    city_number=city_number+1
    #send request to open weather api for each city
    #try/except so it will skip if it doesn't find the data instead of failing
    try:
        city_weather=requests.get(city_url).json()
        #record each item needed for each city
        lat_city= city_weather["coord"]["lat"]
        lng_city= city_weather["coord"]["lon"]
        temp=city_weather["main"]["temp_max"]
        hum= city_weather["main"]["humidity"]
        clouds=city_weather["clouds"]["all"]
        wind= city_weather["wind"]["speed"]
        country=city_weather["sys"]["country"]
        date=city_weather["dt"]
        
        #add info to "city_data_list" in the order I'll want my dataframe
        city_data_list.append({"City":city,
                              "Country":country,
                              "Lat.":lat_city,
                              "Long.":lng_city,
                               "Temperature":temp,
                               "Humidity":hum,
                               "Cloudiness":clouds,
                               "Wind Speed":wind,
                               "Date":date
                              })
        time.sleep(1) #delay to avoid running too many requests per minute.
        #here's where we skip, if data not available
    except:
        print("Data for a city is incomplete. Continuing to next record.")
        print("---------------------------------------------------------")
        time.sleep(1)
        pass
    #log that the data is done loading
print("Done processing all data.")
print("---------------------------------------------------------")
# Out:
# Compiling weather data
# ---------------------------------------------------------
# Processing Record No. 0: malchevskaya
# ---------------------------------------------------------
# Processing Record No. 1: mataura
# ---------------------------------------------------------
# Processing Record No. 2: hervey bay
# ---------------------------------------------------------
# Processing Record No. 3: hilo
# ---------------------------------------------------------
# Processing Record No. 4: vanimo
# ---------------------------------------------------------
# Processing Record No. 5: puerto del rosario
# ---------------------------------------------------------
# Processing Record No. 6: albany
# ---------------------------------------------------------
# Processing Record No. 7: palabuhanratu
# ---------------------------------------------------------
# Data for a city is incomplete. Continuing to next record.
# ---------------------------------------------------------
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df=pd.DataFrame(city_data_list)
city_data_df
# Out:
#                City Country   Lat.   Long.  Temperature  Humidity  Cloudiness  \
# 0      malchevskaya      RU  49.06   40.36        64.76        70          27
# 1           mataura      NZ -46.19  168.86        39.00        83          76
# 2        hervey bay      AU -25.30  152.85        60.01        82         100
# 3              hilo      US  19.73 -155.09        84.20        58           1
# 4            vanimo      PG  -2.67  141.30        82.18        73          66
# ..              ...     ...    ...     ...          ...       ...         ...
# 546          trogir      HR  43.51   16.25        69.80        64           0
# 547     kuusankoski      FI  60.91   26.62        60.80        93          98
# 548          bauchi      NG  10.50   10.00        72.07        88          98
# 549  cabo san lucas      MX  22.89 -109.91        95.00        43          40
# 550           boras      SE  57.72   12.94        53.60        87           0
#
#      Wind Speed        Date
# ...

# %%
city_data_df.to_csv(output_data_file, index_label="City_ID_No.")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#set variables for relevant data from DF
lats=city_data_df["Lat."]
temps=city_data_df["Temperature"]
hums=city_data_df["Humidity"]
clouds2=city_data_df["Cloudiness"]
winds=city_data_df["Wind Speed"]

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lats,temps,c="turquoise",marker="*")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("City Temperatures by Degrees Lat.")
# Out:
# Text(0.5, 1.0, 'City Temperatures by Degrees Lat.')

# %% [markdown]
# In the scatter plot above we see a fairly regular distribution of temperature as it approaches the equator. In other words, as you move closer to the equator, you will have higher temperatures and as you move further away from it, you will have lower temperatures.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lats,hums,c="coral",marker="s")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Humidity Level by Degrees Lat.")
# Out:
# Text(0.5, 1.0, 'City Humidity Level by Degrees Lat.')

# %% [markdown]
# In the scatter plot above, we see the percent of humidity recorded for various cities at different degrees latitude. Most places, regardless of latitude, have some humidity. In fact, from this sample, we see very clear outliers on the low end.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats,clouds2,c="navy",marker="^")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Cloudiness by Degrees Lat.")
# Out:
# Text(0.5, 1.0, 'City Cloudiness by Degrees Lat.')

# %% [markdown]
# In the scatter plot above, we see percent of cloudiness in each city. We see clusters of 0% and 100% due to the fact that cloudiness is subjective - if it is overcast or rainy, then it will likely be considered 100% cloudy, and if we have clear skies, that is 0%. Both of these are common possibilities at any latitude as depicted by the graph.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats,winds,c="grey",marker="o")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Wind Speed by Degrees Lat.")
# Out:
# Text(0.5, 1.0, 'City Wind Speed by Degrees Lat.')

# %% [markdown]
# In the scatter plot above, we see wind speed as compared to latitude. Based on this graph, most places had a wind speed lower than 20 mph today. This is not directly correlated to latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(lats,temps,c="turquoise",marker="*")
plt.xlim(0,80)
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Northern Hemisphere Temperatures by Degrees Lat.")

(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, temps)
print("Slope:%f, Intercept:%f"% (slope,intercept))
x=lats
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:0.023546, Intercept:68.727708

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(lats,temps,c="turquoise",marker="*")
plt.xlim(-60,0)
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("Southern Hemisphere Temperatures by Degrees Lat.")
(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, temps)
print("Slope:%f, Intercept:%f"% (slope,intercept))
x=lats
y=1.6*x+x
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:0.023546, Intercept:68.727708

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(lats,hums,c="coral",marker="s",edgecolor="grey")
plt.xlim(0,80)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere Humidity Level by Degrees Lat.")
(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, hums)
print("Slope:%f, Intercept:%f"% (slope,intercept))
x=lats
y=1.6*x+x
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:-0.062694, Intercept:73.248659

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(lats,hums,c="coral",marker="s",edgecolor="grey")
plt.xlim(-60,0)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere Humidity Level by Degrees Lat.")
(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, hums)
print("Slope:%f, Intercept:%f"% (slope,intercept))
x=lats
y=1.6*x+x
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:-0.062694, Intercept:73.248659

# %% [markdown]
# Again, most of the cities reviewed had a higher than zero humidity level, but there is very little relationship to latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(lats,clouds2,c="navy",marker="^")
plt.xlim(0,80)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere Cloudiness by Degrees Lat.")
(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, clouds2)
print("Slope:%f, Intercept:%f"% (slope,intercept))
x=lats
y=1.6*x+x
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:0.031570, Intercept:51.898435

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(lats,clouds2,c="navy",marker="^")
plt.xlim(-60,0)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere Cloudiness by Degrees Lat.")
(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, clouds2)
print("Slope:%f, Intercept:%f"% (slope,intercept))
x=lats
y=1.6*x+x
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:0.031570, Intercept:51.898435

# %% [markdown]
# Again, there is little relationship between cloudiness and latitude in this sample.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(lats,winds,c="grey",marker="o")
plt.xlim(0,80)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Northern Hemisphere Wind Speed by Degrees Lat.")
(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, winds)
print("Slope:%f, Intercept:%f"% (slope,intercept))
x=lats
y=1.6*x+x
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:-0.000064, Intercept:7.387910

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(lats,winds,c="grey",marker="o")
plt.xlim(-60,0)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Southern Hemisphere Wind Speed by Degrees Lat.")
(slope,intercept,rvalue,pvalue,stderr)=linregress(lats, winds)
print("Slope:%f, Intercept:%f, R Value:%f,P Value:%f,Stderr:%f"% (slope,intercept,rvalue,pvalue,stderr))
x=lats
y=1.6*x+x
plt.plot(x,intercept+slope*x,'r')
# Out:
# Slope:-0.000064, Intercept:7.387910, R Value:-0.000418,P Value:0.992185,Stderr:0.006559

# %% [markdown]
# As you can see, this regression line shows no statistically relevant relationship between wind speed and latitude.

# %% [markdown]
# # Analysis

# %% [markdown]
# In our random sample here, wind speed is usually very low (less than 10 mph) for any latitude. Additionally, cloudiness, has little to do with latitude. However, temperature does increase as we approach the equator, which proves it has the theorized impact. The really interesting finding is that the data leans to a lower temperature in the southern hemisphere, demonstrating the degree of tilt of the Earth's axis, and that tilt's impact on temperatures across the globe.
